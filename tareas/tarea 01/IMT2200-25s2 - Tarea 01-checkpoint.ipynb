# %% [markdown]
# IMT 2200 - Introducción a Ciencia de Datos<br>
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>
#
# ---
#
# ## Tarea 01 – Cargando y Analizando Datos
#
# - **Fecha de Entrega:** martes 26 de agosto de 2025, a las 23:59.
# -
# **Formato de entrega:** Notebook ejecutado y comentado (`.ipynb`) en l emódulo de Tara 01 habilitado en Canvas.

# %% [markdown]
# ## Instrucciones
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
# - Notebook **autocontenible** que:
#    - Ejecute sin errores todas las celdas.
#   - Contenga tanto el código como los comentarios y explicaciones necesarias.
#   - Incluya visualizaciones claras y correctamente etiquetadas.
# - No se aceptarán notebooks con celdas rotas o que dependan de rutas externas no indicadas en la tara.
#
# - Deben hacer sus consultas y comentarios sobre la Tarea a traves del canal de Tareas en eo del curso en Canvas.os.
# cteriza.

# %% [markdown]
# ## 1. Objetivos
#
# - Aplicar los conceptos iniciales de manejo de datos y análisis exploratorio vistos en clases.
# - Practicar la lectura, limpieza y manipulación de datos en Python.
# - Desarrollar habilidades para visualizar y describir patrones y tendencias en conjuntos de datos reales.
# - Fomentar la capacidad de comunicar resultados de forma clara y fundamentada.
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la lectura y exploración de datos.
#
# Para los ejercicios a continuación, usted deberá leer, inspeccionar, manipular y graficar conjuntos de datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# Para esta tarea, tendremos como objetivo comprender cómo han cambiado los juegos de mesa en los últimos 40 años. Específicamente queremos saber qué tipos de juegos se han vuelto más comunes hoy en día y qué los caracteriza.
#
# ### 1.3 Recomendaciones
# - Utiliza las librerías sugeridas en el notebook o justifica brevemente si incorporas otras.
# - Revisa que todas las celdas se ejecuten en orden, desde el inicio, sin errores.
# - Comenta tu código para explicar qué hace cada sección relevante.
# - Asegúrate de que las visualizaciones sean fáciles de interpretar y tengan títulos y etiquetas adecuados.

# %% [markdown]
# ## 2. Datos
#
# Estaremos utilizando información extraída desde [BoardGameGeek.com](https://boardgamegeek.com/), una plataforma para aficionados de los juegos de mesa, que permite a sus usuarios registrar, calificar e intercambiar sus juegos favoritos. Actualmente, BGG es una de las bases de datos más extensa y diversa de juegos de mesa.
#
# El dataset con el que trabajaremos consiste en un grupo de archivos CSV que contienen información sobre más de 100.000 juegos de mesa almacenados en la plataforma. Este puede descargarse directamente desde el siguiente enlace: https://www.kaggle.com/datasets/mshepherd/board-games Para descargar los datos, haga click en el botón de **Download**, donde podrá descargar los archivos como `.zip`, o bien utilizar la API de Kaggle.
#
# Para el desarrollo de esta tarea, solo utilizaremos los archivos con el prefijo `bgg_`.
#
# **Si utiliza la API de Kaggle para descargar los datos, deje el código utilizado en la siguiente celda:**

# %%
# Descarga de datos desde Kaggle

# %% [markdown]
# ### 2.1 Librerías
#
# Para esta tarea recomendamos al menos usar las librerías indicadas en la siguiente celda del Notebook. Puede agregar otras si lo estima conveniente para responder de mejor forma las preguntas de la Tarea.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## 3. Desarrollo
#
# Para cada una de las siguientes preguntas o actividades incluya una o más celdas de código y Markdown con las respuestas o comentarios necesarios para contestar la pregunta o lograr la actividad. Agregue sus celdas a continuación de cada pregunta para que el Notebook quede ordenado.
#
# En el caso de gráficos, figuras o tablas, asegúrese que todas tengan título, etiquetas en los ejes o haya claridad de los contenidos.

# %% [markdown]
# ### 3.1 DataFrame unificado (1 punto)
#
# Vamos a cargar en un DataFrame los datos de juegos guardados en el documento `bgg_GameItem.csv`. Al inspeccionar nuestros datos, podemos notar que los valores de ciertas comunas vienen "codificados" con ID. Para comenzar, vamos a juntar la información de los distintos archivos descargados.
#
# **a) (0.8 pts)** Genere un DataFrame único con toda la información de cada juego, incluyendo: nombres de artistas y diseñadores involucrados, mecánicas, categorías, tipo, familia y editorial. Guarde este DataFrame en un nuevo archivo CSV.

# %% [markdown]
# a) El DataFrame está en un nuevo archivo llamado DataFrame_InfoJuegos.txt

# %%
ruta = os.path.join("archive" ,  "bgg_GameItem.csv")
#data = pd.read_csv(ruta)
#data
ruta_a = os.path.join("archive", "bgg_Category.csv")
ruta_b = os.path.join("archive", "bgg_GameFamily.csv")
ruta_c = os.path.join("archive", "bgg_GameType.csv")
ruta_d = os.path.join("archive", "bgg_Mechanic.csv")
ruta_e = os.path.join("archive", "bgg_Person.csv")
ruta_f = os.path.join("archive", "bgg_Publisher.csv")


leer_archivo = pd.read_csv(ruta)
leer_archivo_c = pd.read_csv(ruta_c)
leer_archivo = leer_archivo.astype(str)
leer_archivo_c = leer_archivo_c.astype(str)
leer_archivo_a = pd.read_csv(ruta_a)
leer_archivo_a = leer_archivo_a.astype(str)
leer_archivo_b = pd.read_csv(ruta_b)
leer_archivo_b = leer_archivo_b.astype(str)
leer_archivo_d = pd.read_csv(ruta_d)
leer_archivo_d = leer_archivo_d.astype(str)
leer_archivo_e = pd.read_csv(ruta_e)
leer_archivo_e = leer_archivo_e.astype(str)
leer_archivo_f = pd.read_csv(ruta_f)
leer_archivo_f = leer_archivo_f.astype(str)

#resultado = leer_archivo.join(leer_archivo_c)
#leer_archivo["bgg_id"] = leer_archivo["bgg_id"].astype(int)

#leer_archivo_c = pd.read_csv(ruta_c)

#leer_archivo.head(10)
#leer_archivo_c.groupby("ID")[name]
#path_relativo = ruta
leer_archivo_c = leer_archivo_c.rename(columns = {"bgg_id": "id_type","name": "name_type"})
leer_archivo_b = leer_archivo_b.rename(columns = {"bgg_id": "id_family","name": "name_family"})
leer_archivo_a = leer_archivo_a.rename(columns = {"bgg_id": "id_category","name": "name_category"})
leer_archivo_d = leer_archivo_d.rename(columns = {"bgg_id": "id_mechanic","name": "name_mechanic"})  #cambios de nombre a las columnas para evitar                                                                                                       
leer_archivo_e = leer_archivo_e.rename(columns = {"bgg_id": "id_person","name": "name_person"})      #errores por los mismos nombres
leer_archivo_f = leer_archivo_f.rename(columns = {"bgg_id": "id_publisher","name": "name_publisher"})

leer_archivo["designer"] = leer_archivo["designer"].str.split(",")   #hacemos una lista con los numeros designer y artist
leer_archivo["artist"] = leer_archivo["artist"].str.split(",")

leer_archivo = leer_archivo.explode("designer") #hacemos una lista con los numeros designer y artist
leer_archivo = leer_archivo.explode("artist")  #ocuparemos explode que aprendimos en la ayudantía



leer = pd.merge(leer_archivo, leer_archivo_c , left_on = "game_type", right_on = "id_type", how = "left")
leer["game_type"] = leer["name_type"]
#leer_archivo = leer_archivo.drop(columns = ["bgg_id", "name"])
leer = pd.merge(leer, leer_archivo_a , left_on = "category", right_on = "id_category", how = "left")
leer["category"] = leer["name_category"]

#leer_archivo = leer_archivo.drop(columns = ["bgg_id", "name"])
leer = pd.merge(leer, leer_archivo_b , left_on = "family", right_on = "id_family", how = "left")
leer["family"] = leer["name_family"]

leer = pd.merge(leer, leer_archivo_d , left_on = "mechanic", right_on = "id_mechanic", how = "left")
leer["mechanic"] = leer["name_mechanic"]

leer = pd.merge(leer, leer_archivo_e.rename(columns = {"name_person":"person_designer"}) , left_on = "designer", right_on = "id_person", how = "left")
leer["designer"] = leer["person_designer"] 
leer = pd.merge(leer, leer_archivo_e.rename(columns = {"name_person":"person_artist"}) , left_on = "artist", right_on = "id_person", how = "left")
leer["artist"] = leer["person_artist"]


leer = pd.merge(leer, leer_archivo_f , left_on = "publisher", right_on = "id_publisher", how = "left")
leer["publisher"] = leer["name_publisher"]
#leer_archivo = leer_archivo.drop(columns = ["bgg_id", "name"])
#resultado
leer
leer.to_csv("Data_frame_games", index = False)  #crear el archivo del dataframe

#leer_archivo
#with open(path_relativo, "rt", encoding = "utf-8" ) as archivo:
 #   lineas = archivo.readlines()

#print(lineas)
#print(ruta)

# %%
ruta = os.path.join("archive", "bgg_GameItem.csv")
#ruta_c = os.path.join("tareas", "tarea 01", "archive", "bgg_GameType.csv")
#leer_archivo_c = pd.read_csv(ruta_c)
data = pd.read_csv(ruta)
data
#cambio = leer_archivo_c.rename(columns = {"name": "type_name"})
#print(cambio)
# Out:
#         bgg_id                           name    year game_type  \
# 0            1                     Die Macher  1986.0      5497
# 1            2                   Dragonmaster  1981.0      5497
# 2            3                        Samurai  1998.0      5497
# 3            4                 Tal der Könige  1992.0      5497
# 4            5                        Acquire  1964.0      5497
# ...        ...                            ...     ...       ...
# 113899  391565                     Champions!  2023.0       NaN
# 113900  391715           Leitin að stjörnunni  2022.0       NaN
# 113901  391720  The String Railway Collection  2024.0       NaN
# 113902  391834                      SpellBook  2023.0       NaN
# 113903  392146            Nightmares of Sushi  2023.0       NaN
#
#                     designer       artist  \
# 0                          1   12517,4959
# 1                       8384        12424
# 2                          2        11883
# 3                       8008         2277
# 4                          4  12658,18317
# ...                      ...          ...
# 113899      62310,62311,6736          NaN
# 113900  154290,123339,154289          NaN
# 113901                 39436       113637
# 113902                  8347        45292
# 113903                 81537        81537
#
#                                                 publisher  min_players  \
# 0            133,2,24883,2726,15108,39249,11652,5382,8147          3.0
# 1                                                   64,20          3.0
# 2       17,133,267,29,7340,7335,41,2973,4617,1391,8291...          2.0
# 3                                                      37          2.0
# 4       92,5,4871,3082,858,2962,28072,5392,4668,38,462...          2.0
# ...                                                   ...          ...
# 113899                                          4384,1391          3.0
# 113900                                              54258          2.0
# 113901                                              44392          2.0
# 113902                                              25842          1.0
# 113903                                              52244          2.0
#
#         max_players  min_players_rec  ...  stddev_rating  bayes_rating  \
# 0               5.0              4.0  ...        1.57510       7.06367
# 1               4.0              3.0  ...        1.46752       5.76599
# 2               4.0              2.0  ...        1.19279       7.22869
# 3               4.0              2.0  ...        1.23667       5.66660
# 4               6.0              3.0  ...        1.33603       7.12541
# ...             ...              ...  ...            ...           ...
# 113899          8.0              3.0  ...            NaN           NaN
# 113900         20.0              2.0  ...            NaN           NaN
# 113901          5.0              2.0  ...            NaN           NaN
# 113902          4.0              1.0  ...            NaN           NaN
# 113903          6.0              2.0  ...            NaN           NaN
#
#         complexity  language_dependency  bga_id  dbpedia_id  luding_id  \
# 0           4.3144             1.166667     NaN         NaN        NaN
# 1           1.9636                  NaN     NaN         NaN        NaN
# 2           2.4784             1.006579     NaN         NaN        NaN
# 3           2.6667                  NaN     NaN         NaN        NaN
# 4           2.4985             1.095890     NaN         NaN        NaN
# ...            ...                  ...     ...         ...        ...
# 113899         NaN                  NaN     NaN         NaN        NaN
# 113900         NaN                  NaN     NaN         NaN        NaN
# 113901         NaN                  NaN     NaN         NaN        NaN
# 113902         NaN                  NaN     NaN         NaN        NaN
# 113903         NaN                  NaN     NaN         NaN        NaN
#
#        spielen_id wikidata_id  wikipedia_id
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ...           ...         ...           ...
# 113899        NaN         NaN           NaN
# 113900        NaN         NaN           NaN
# 113901        NaN         NaN           NaN
# 113902        NaN         NaN           NaN
# 113903        NaN         NaN           NaN
#
# [113904 rows x 38 columns]

# %% [markdown]
# **b) (0.2 pts)** ¿Cuánto espacio en disco ocupa este DataFrame? ¿Cuánto espacio en disco ocupan los documentos CSV separados? ¿A qué se debe esta diferencia? Comente.

# %% [markdown]
# b)Este DataFrame ocupa 51.109KB de disco.
# Los documentos CSV separados ocupan 35.888 en espacio.
# Los DataFrame con pd.read_csc("") optimiza los datos de manera eficiente, por ejemplo evita guardar cosas con str, ya que ucupan mucho almacenamiento, pero el archivo que creé "Data_frame_games" poseé más a comparación con los documentos CSV separados debido a que tiene varias columnas repetidas con nombres distintos que deberían ser borradas.

# %% [markdown]
# ### 3.2 Juegos publicados anualmente (1.5 puntos)
#
#
# **a) (0.5 pts)** Limpie los datos para dejar solo aquellos que tienen valores válidos de año de publicación. Luego responda: ¿cuál es el rango de años con el que estamos trabajando? ¿Tienen sentido estos años?
#
# respuesta: Estamos trabajando en el rango de 1960-2025. Sí porque vemos que tanto a ido creciendo la cantidad de videojuegos con el paso de los años.

# %%
leer.info()
print(f"Las columnas son : ") # nos muestra los nombres de las columnas
for col in leer.columns: #/lista con os nombres de cada columna
    print(f" - {col}")

print("="*80)
print(f"Las estadísticas descriptivas están para la(s) columna(s) : {leer.describe()}")


year = leer['year'].value_counts()

#years = years.sort_index()
rango = years[(years.index >= 1900) & (years.index <= 2025)]

# ploteamos los primeros 10
plt.figure(figsize=(12, 6))
plt.bar(rango.index, rango.values, color = "orange")
plt.title('Juegos por año')
plt.xlabel('años')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.show()

#dramas = df[df['listed_in'].str.contains("Dramas")] #/ ej: dramas comedy
#dramas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178226 entries, 0 to 178225
# Data columns (total 52 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   bgg_id               178226 non-null  object
#  1   name                 178226 non-null  object
#  2   year                 167187 non-null  float64
#  3   game_type            50957 non-null   object
#  4   designer             159751 non-null  object
#  5   artist               104410 non-null  object
#  6   publisher            130831 non-null  object
#  7   min_players          178226 non-null  object
#  8   max_players          178226 non-null  object
#  9   min_players_rec      178226 non-null  object
#  10  max_players_rec      178226 non-null  object
#  11  min_players_best     178226 non-null  object
#  12  max_players_best     178226 non-null  object
#  13  min_age              178226 non-null  object
#  14  min_age_rec          178226 non-null  object
#  15  min_time             178226 non-null  object
#  16  max_time             178226 non-null  object
#  17  category             36234 non-null   object
#  18  mechanic             46226 non-null   object
#  19  cooperative          178226 non-null  object
#  20  compilation          178226 non-null  object
#  21  compilation_of       178226 non-null  object
#  22  family               47637 non-null   object
#  23  implementation       178226 non-null  object
#  24  integration          178226 non-null  object
#  25  rank                 178226 non-null  object
#  26  num_votes            178226 non-null  object
#  27  avg_rating           178226 non-null  object
#  28  stddev_rating        178226 non-null  object
#  29  bayes_rating         178226 non-null  object
#  30  complexity           178226 non-null  object
#  31  language_dependency  178226 non-null  object
#  32  bga_id               178226 non-null  object
#  33  dbpedia_id           178226 non-null  object
#  34  luding_id            178226 non-null  object
#  35  spielen_id           178226 non-null  object
#  36  wikidata_id          178226 non-null  object
#  37  wikipedia_id         178226 non-null  object
#  38  id_type              50957 non-null   object
#  39  name_type            50957 non-null   object
#  40  id_category          36234 non-null   object
#  41  name_category        36234 non-null   object
#  42  id_family            47637 non-null   object
#  43  name_family          47637 non-null   object
#  44  id_mechanic          46226 non-null   object
#  45  name_mechanic        46226 non-null   object
#  46  id_person_x          159751 non-null  object
#  47  person_designer      159751 non-null  object
#  48  id_person_y          104410 non-null  object
#  49  person_artist        104410 non-null  object
#  50  id_publisher         130831 non-null  object
#  51  name_publisher       130831 non-null  object
# dtypes: float64(1), object(51)
# memory usage: 70.7+ MB
# Las columnas son :
#  - bgg_id
#  - name
#  - year
#  - game_type
#  - designer
#  - artist
#  - publisher
#  - min_players
#  - max_players
#  - min_players_rec
#  - max_players_rec
#  - min_players_best
#  - max_players_best
#  - min_age
#  - min_age_rec
#  - min_time
#  - max_time
#  - category
#  - mechanic
#  - cooperative
#  - compilation
#  - compilation_of
#  - family
#  - implementation
#  - integration
#  - rank
#  - num_votes
#  - avg_rating
#  - stddev_rating
#  - bayes_rating
#  - complexity
#  - language_dependency
#  - bga_id
#  - dbpedia_id
#  - luding_id
#  - spielen_id
#  - wikidata_id
#  - wikipedia_id
#  - id_type
#  - name_type
#  - id_category
#  - name_category
#  - id_family
#  - name_family
#  - id_mechanic
#  - name_mechanic
#  - id_person_x
#  - person_designer
#  - id_person_y
#  - person_artist
#  - id_publisher
#  - name_publisher
# ================================================================================
# Las estadísticas descriptivas están para la(s) columna(s) :                 year
# count  167187.000000
# mean     2003.551448
# std        67.742745
# min     -3500.000000
# 25%      2000.000000
# 50%      2011.000000
# 75%      2018.000000
# max      2026.000000

# %% [markdown]
# **b) (0.5 pts)** Seleccione solamente los juegos entre los años 1980 y 2025. Luego grafique la cantidad de juegos publicados por año. ¿Cómo es esta tendencia? Comente.
#
#
# respuesta: La tendecia es creciente, hasta diría que de forma exponencial

# %%
year = leer['year'].value_counts()

#years = years.sort_index()
rango = years[(years.index >= 1980) & (years.index <= 2025)]

# ploteamos los primeros 10
plt.figure(figsize=(12, 6))
plt.bar(rango.index, rango.values, color = "orange")
plt.title('Juegos por año')
plt.xlabel('años')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **c) (0.5 pts)** ¿Entre qué años hubo un mayor aumento de publicación de juegos de mesa según los registros de BGG?

# %% [markdown]
# ### 3.3 Análisis de duración y complejidad (1.5 puntos)
#
# Si bien hay muchas posibles características que podemos explorar para los juegos de mesa, esta vez nos centraremos en el tiempo de juego y la complejidad. En esta sección queremos comprender si se ha modificado notablemente la duración promedio y la percepción de complejidad de los juegos de mesa a través de los años.

# %% [markdown]
# **a) (0.3 pts)** Inspecciones y filtre los datos que tengan valores válidos para: tiempo mínimo de juego, tiempo máximo de juego y complejidad. En el caso de que existan "outliers", puede descartarlos, cosiderando un rango razonable para las variables anteriores. Justifique su desición.

# %% [markdown]
# **b) (0.2 pts)** Veremos ahora si ha cambiado la duración promedio de los juegos de mesa en nuestro rango de años seleccionado. Primero, cree una nueva columna `avg_time` en el dataset con la duración promedio supuesta para cada juego.

# %% [markdown]
# **c) (0.5 pts)** Grafique la duración promedio de juegos al año entre 1980 y 2025. ¿Existe alguna tendencia? Asegúrese de colocar las unidades correspondientes en sus ejes si es necesario. Comente sus resultados.

# %% [markdown]
# **d) (0.5 pts)** Nos interesa saber si los juegos de mesa recientes son más complejos que aquellos publicados antes de los 2000. BoardGameGeek permite evaluar la complejidad (o "weight") de un juego en una escala de 1 a 5, siendo 1 un juego "liviano" o fácil de entender, y 5 un juego "pesado" o complejo. Primero, seleccione los juegos que han sido evaluados por al menos 100 usuarios. Luego grafique la complejidad promedio de los juegos según año. Responda: ¿ha cambiado la percepción de complejidad entre juegos entre 1980 y la actualidad?

# %% [markdown]
# ### 3.4 Análisis de categorías comunes (2 puntos)
#
# Existe una gran diversidad de categorías de juegos de mesa. Ahora nos concentraremos en un grupo específico de ellas, con el fin de analizar cómo a cambiado la cantidad de juegos de estas clases desde 1980 hasta hoy.
#
# **a) (0.7 pts)** ¿Cuáles son las 5 categorías más comunes en los juegos del dataset? Muestre la cantidad de juegos que hay de cada una. Puede graficar estos valores, o bien, entregar un DataFrame con sus valores.

# %% [markdown]
# **b) (0.3 pts)** Para cada una de estas 5 categorías, cree un DataFrame que contenga la cantidad de juegos en el dataset según año. Luego junte estos DataFrames en uno solo con los atributos de "Año", "Categoría" y "Cantidad".

# %% [markdown]
# **c) (1 pto)** Grafique, en un solo gráfico y con distintos colores, la cantidad de juegos por año según categoría. Preocúpese de ponerle etiquetas al gráfico para identificar cada categoría y una leyenda donde se muestre cada una. Comente: ¿ha habido un cambio entre los juegos más comunes en los años 80 y hoy?

# %% [markdown]
# ### 3.5 Análisis Crítico (Bono +0.5 puntos)
#
# ¿Qué limitaciones o problemas encontraste en los datos?
